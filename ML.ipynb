# %%
import pandas as pd 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
data = pd.read_csv('Student Mental health.csv')
label = LabelEncoder()
data['What is your course?'] = label.fit_transform(data['What is your course?'])
data.head()
# Out:
#         Timestamp Choose your gender   Age  What is your course?  \
# 0  8/7/2020 12:02             Female  18.0                    17
# 1  8/7/2020 12:04               Male  21.0                    25
# 2  8/7/2020 12:05               Male  19.0                     4
# 3  8/7/2020 12:06             Female  22.0                    33
# 4  8/7/2020 12:13               Male  23.0                    37
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
# x = data.drop('', axis=1)

# %%
sns.get_dataset_names()
DATA = sns.load_dataset('iris')
x=DATA.iloc[:, 0:3]
print(x)
y=DATA['species']
# Out:
#      sepal_length  sepal_width  petal_length
# 0             5.1          3.5           1.4
# 1             4.9          3.0           1.4
# 2             4.7          3.2           1.3
# 3             4.6          3.1           1.5
# 4             5.0          3.6           1.4
# ..            ...          ...           ...
# 145           6.7          3.0           5.2
# 146           6.3          2.5           5.0
# 147           6.5          3.0           5.2
# 148           6.2          3.4           5.4
# 149           5.9          3.0           5.1
#
# [150 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
sns.get_dataset_names()
DATA = sns.load_dataset('iris')
x=DATA.iloc[:, 0:3]
print(x)
y=DATA['species']

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7)

print()
# Out:
#      sepal_length  sepal_width  petal_length
# 0             5.1          3.5           1.4
# 1             4.9          3.0           1.4
# 2             4.7          3.2           1.3
# 3             4.6          3.1           1.5
# 4             5.0          3.6           1.4
# ..            ...          ...           ...
# 145           6.7          3.0           5.2
# 146           6.3          2.5           5.0
# 147           6.5          3.0           5.2
# 148           6.2          3.4           5.4
# 149           5.9          3.0           5.1
#
# [150 rows x 3 columns]

# %%
import pandas as pd
import sklearn.preprocessing as LabelEncoder
from sklearn.model_selection import train_test_split

data = pd.read_csv('Salary.csv')
# data.head()

x = data.iloc[:, 0]
y = data.iloc[:, 1]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (24,) (11,) (24,) (11,)

# %% [markdown]
# # Car Data set

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# Label Encoding
data =  pd.read_csv('cars.csv')
label = LabelEncoder()
data["Car"] = label.fit_transform(data["Car"])
data["Model"] = label.fit_transform(data["Model"])

# Seprating features and Target values
x = data.drop('Model', axis = 1)
y = data["Model"]

# %%
# Normalization
min = MinMaxScaler()
x = min.fit_transform(x)
print(x)
# Out:
# [[0.875      0.0625     0.         0.3       ]
#  [0.625      0.1875     0.38702929 0.16666667]
#  [0.75       0.0625     0.14539749 0.16666667]
#  [0.125      0.         0.07845188 0.        ]
#  [0.5625     0.375      0.36610879 0.5       ]
#  [0.9375     0.0625     0.14539749 0.5       ]
#  [0.75       0.3125     0.33368201 0.        ]
#  [0.5        0.375      0.60146444 0.06666667]
#  [0.1875     0.375      0.33682008 0.26666667]
#  [0.         0.4375     0.37656904 0.3       ]
#  [0.375      0.125      0.19874477 0.3       ]
#  [0.8125     0.25       0.20920502 0.36666667]
#  [0.1875     0.0625     0.33682008 0.3       ]
#  [0.25       0.4375     0.4832636  0.13333333]
#  [0.3125     0.4375     0.56066946 0.23333333]
#  [0.6875     0.4375     0.56485356 0.23333333]
#  [0.0625     0.4375     0.60146444 0.3       ]
#  [0.4375     0.8125     0.5125523  0.46666667]
#  [0.75       0.4375     0.34414226 0.46666667]
#  [0.1875     0.6875     0.56276151 0.5       ]
# ...

# %%
# Standization
scale = StandardScaler()
x = scale.fit_transform(x)
print(x)
# Out:
# [[ 1.27418685 -1.59336644 -2.10389253 -0.41192538]
#  [ 0.48331225 -1.07190106 -0.55407235 -0.95612037]
#  [ 0.87874955 -1.59336644 -1.52166278 -0.95612037]
#  [-1.09843694 -1.85409913 -1.78973979 -1.63636411]
#  [ 0.2855936  -0.28970299 -0.63784641  0.40436711]
#  [ 1.4719055  -1.59336644 -1.52166278  0.40436711]
#  [ 0.87874955 -0.55043568 -0.76769621 -1.63636411]
#  [ 0.08787496 -0.28970299  0.3046118  -1.36426661]
#  [-0.90071829 -0.28970299 -0.7551301  -0.54797412]
#  [-1.49387424 -0.0289703  -0.59595938 -0.41192538]
#  [-0.30756234 -1.33263375 -1.30803892 -0.41192538]
#  [ 1.0764682  -0.81116837 -1.26615189 -0.13982788]
#  [-0.90071829 -1.59336644 -0.7551301  -0.41192538]
#  [-0.70299964 -0.0289703  -0.16871166 -1.09216911]
#  [-0.50528099 -0.0289703   0.14125238 -0.68402287]
#  [ 0.6810309  -0.0289703   0.15800719 -0.68402287]
#  [-1.29615559 -0.0289703   0.3046118  -0.41192538]
#  [-0.10984369  1.53542584 -0.05142797  0.26831836]
# ...

# %%
# Regression
from sklearn.model_selection import linearRegression
model = linearRegression()

# %% [markdown]
# #  Petrol Dataset

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

data =  pd.read_csv('Petrol.csv', encoding = 'latin-1')
label = LabelEncoder()
data["Country"] = label.fit_transform(data["Country"])

# data["World Share"].astype('str') 
data["World Share"] = label.fit_transform(data["World Share"].str.replace('%',''))

# x = data.iloc[:,:-1]
# y = data["Price Per Liter (PKR)"]
# y = data.iloc[:,-1]

# x_train, x_test, y_train, y_test = train_test_split(x, y, train_size =0.7, random_state = 0)
# min = MinMaxScaler(feature_range = (0,1))

# data["Price Per Liter (PKR)"] = min.fit_transform(data["Price Per Liter (PKR)"])

data
# Out:
#        #  Country  Daily Oil Consumption (Barrels)  World Share  \
# 0      1      172                         19687287           31
# 1      2       35                         12791553           26
# 2      3       72                          4443000           36
# 3      4       80                          4012877           35
# 4      5      134                          3631287           34
# ..   ...      ...                              ...          ...
# 176  177      137                              660            0
# 177  178       84                              400            0
# 178  179      107                              400            0
# 179  180      136                               70            0
# 180  181      118                               51            0
#
#      Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 0                        934.3                    5.19                   1.37
# ...

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>
